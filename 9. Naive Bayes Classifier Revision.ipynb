# %% [markdown]
# # Naive Bayes Classifier Algorithm
#
# 1. Naive Bayes algorithm is a supervised learning algorithm, which is based on Bayes theorem and used
#    for solving classification problems.
# 2. It is mainly used in text classification that includes a high-dimensional training dataset.
# 3. It is a probabilistic classifier, which means it predicts on the basis of the probability of an object.
# 4. It assumes that each input variable is independent.
# 5. Naive Bayes Classifier is one of the simple and most effective Classification algorithms which helps
#    in building the fast machine learning models that can make quick predictions.
# 6. Some popular examples of Naïve Bayes Algorithm are spam filtration, Sentimental analysis, and Text Classification.

# %% [markdown]
# # Why is it called Naive Bayes
#
# #### Naive:
# * It is called Naïve because it assumes that the occurrence of a certain feature is independent of the
#   occurrence of other features.
#
# #### Bayes:
# * It is called Bayes because it depends on the principle of Bayes' Theorem.

# %% [markdown]
# # Types of Naive Bayes Algorithms
#
# #### Gaussian: (Continuous Data)
# 1. The Gaussian model assumes that features follow a normal distribution.
# 2. This means if predictors take continuous values instead of discrete.
#
# #### Multinomial: (TF-IDF )
# 1. The Multinomial Naive Bayes classifier is used when the data is multinomial distributed.
# 2. The classifier uses the frequency of words for the predictors.
#
# #### Bernoulli: (Binary Data)
# 1. The Bernoulli classifier works similar to the Multinomial classifier, but the predictor variables
#    are the independent Booleans variables(i.e. True/False).
# 2. Such as if a particular word is present or not in a document.
# 3. This model is also famous for document classification tasks.

# %% [markdown]
# # Bayes' Theorem
#
# 1. Bayes' theorem is also known as Bayes' Rule or Bayes' law, which is used to determine the probability
#    of a hypothesis with prior knowledge.
# 2. It depends on the conditional probability.
# 3. The formula for Bayes' theorem is given as:
#    * P(A|B) = (P(B|A) * P(B))/P(A)
#
#      Where,
#
#      P(A|B) is Posterior probability: Probability of hypothesis A on the observed event B.
#
#      P(B|A) is Likelihood probability: Probability of the evidence given that the probability of a hypothesis is true.
#
#      P(A) is Prior Probability: Probability of hypothesis before observing the evidence.
#
#      P(B) is Marginal Probability: Probability of Evidence.

# %%
Image(r'E:\Images\Naive Bayes\1_a.png',width = 500)

# %%
Image(r'E:\Images\Naive Bayes\204.png',width = 500)

# %%
Image(r'E:\Images\Naive Bayes\1_V.jpeg',width = 500)

# %% [raw]
# P(A|B) >> Probability of A when B is given.
#
# P(A|B) = P(A^B) / P(A) >> Conditional Probability
# P(B|A) = P(B^A) / P(B)
#
# P(A^B) = P(A|B) * P(A)
# P(B^A) = P(B|A) * P(B)
#
# P(A|B) * P(A) = P(B|A) * P(B)
#
# P(A|B) = (P(B|A) * P(B))/P(A) >> Bayes Theorem
#
# Posterior probability =
#
# (Likelihood probability * Prior Probability) / Marginal Probability

# %% [raw]
# P(Y|X) = (P(X|Y) * P(Y))/P(X)
#
# P(Y=1|X{x1,x2,x3}) = ( P(x1|Y) * P(x2|Y) * P(x3|Y) * P(Y=1) ) / P(x1) * P(x2) * P(x3)
#
# P(Y=0|X{x1,x2,x3}) = ( P(x1|Y) * P(x2|Y) * P(x3|Y) * P(Y=0) ) / P(x1) * P(x2) * P(x3)

# %% [markdown]
# # Working of Naive Bayes' Classifier
#
# 1. Convert the given dataset into frequency tables.
# 2. Find the probabilities of given features.
# 3. Now, use Bayes theorem to calculate the posterior probability.

# %% [raw]
# Frequency Table:
#
# P(yes) = 9/14
# P(no) = 5/14
#
# Outlook:
#
#            Yes    No   P(Yes)                  P(No)
# Overcast    4      0   4/9 P(Overcast|Yes)   0/5 P(Overcast|No)
# rainy       3      2   3/9 P(rainy|Yes)      2/5 P(rainy|No)
# sunny       2      3   2/9 P(Sunny|Yes)      3/5 P(Sunny|No)
#             9      5
#
#
# temperature:
#         Yes   No    P(Yes)             P(No)
# hot     2     2      2/9 P(hot|Yes)     2/5 P(hot|No)
# cool    3     1      3/9 P(cool|Yes)    1/5 P(cool|No)
# mild    4     2      4/9 P(mild|Yes)    2/5 P(mild|No)
#         9     5
#
#
# Prior Prob:
# P(Y) = 9/14
# P(N) = 5/14
#
# P(Y=1|X{x1,x2}) = ( P(x1|Y) * P(x2|Y) * P(Y=1) ) / P(x1) * P(x2)
#
# P(Yes|(Outlook=Sunny,temp=Hot)) =
#
#        (P(Sunny|Yes) * P(hot|Yes) * P(Yes)) / P(Sunny) * P(Hot)
#
#        =  (2/9) * (2/9) * (9/14) = 0.0317
#
# P(No|(Outlook=Sunny,temp=Hot)) =
#
#        (P(Sunny|No) * P(hot|No) * P(No)) / P(Sunny) * P(Hot)
#
#        =  (3/5) * (2/5) * (5/14) = 0.0857
#
#
# Normalize Probability >>
# P(Yes) =  0.0317 / (0.0317 + 0.0857) = 0.27
# P(No) =  0.0857 / (0.0317 + 0.0857)  = 0.73

# %% [markdown]
# # Advantages of Naive Bayes Classifier
#
# 1. Naive Bayes is one of the fast and easy ML algorithms to predict a class of datasets.
# 2. It can be used for Binary as well as Multi-class Classifications.
# 3. It performs well in Multi-class predictions as compared to the other Algorithms.
# 4. It is the most popular choice for text classification problems.

# %% [markdown]
# # Disadvantages of Naive Bayes Classifier
#
# 1. Naive Bayes assumes that all features are independent or unrelated, so it cannot learn the relationship between features.

# %% [markdown]
# # Applications of Naive Bayes Classifier
#
# 1. It is used for Credit Scoring.
# 2. It is used in medical data classification.
# 3. It can be used in real-time predictions because Naive Bayes Classifier is an eager learner.
# 4. It is used in Text classification such as Spam filtering and Sentiment analysis.
